# %%
# Визуализировать распределение времени жизни авторов в зависимости от страны
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def dt_parse(x):  # standard parser does not work due to its ranges
    if x == "nan":
        return "nan"
    year, month, day = x.split('-')
    return pd.Period(
        year=int(year),
        month=int(month),
        day=int(day),
        freq='D')

dataframe = pd.read_table(
    'data.tsv',
    parse_dates=['birth_date', 'death_date'],
    date_parser=dt_parse)

dataframe['lifespan'] = dataframe.apply(
    lambda x: 0 if x.death_date == "nan" or x.birth_date == "nan"
        else (x.death_date - x.birth_date) / 365, axis=1)

def get_country(df):
    return df.death_place.split(',')[-1] if type(df.death_place) is str else \
        df.birth_place.split(',')[-1] if type(df.birth_place) is str else ''

dataframe['country'] = dataframe.apply(get_country, axis=1)

dataframe[['lifespan', 'country']].groupby('country').mean()

#cities = pd.read_csv('http://download.maxmind.com/download/worldcities/worldcitiespop.txt.gz')
#cities[['city', 'country', 'latitude', 'longitude']]
# Out:
#                                                       lifespan
# country
#                                                      17.824384
#  (Атырау)                                             0.000000
#  (теперь Израиль)                                    77.567123
#  (штат Флорида)                                      72.312329
#  Alaska                                              90.780822
#  Alpes-Maritimes (Provence-Alpes-Cote d'Azur) [...   72.219178
#  Argentina                                           35.189041
#  Arizona                                             82.857534
#  Arkansas                                             0.000000
#  Asturias                                             0.000000
#  Australia                                           18.769863
#  Austria                                             57.684932
#  Birmingham                                          74.542466
#  Brandenburg                                          0.000000
#  Brazil                                               0.000000
#  British Columbia                                     0.000000
#  Bulawayo                                             0.000000
#  CA                                                   0.000000
#  CCCР                                                55.063014
#  California                                          49.997808
#  California U.S.A.                                    0.000000
#  Canada                                               0.000000
#  Colombia                                             0.000000
#  Connecticut                                         86.345205
#  Cork.                                               36.405479
#  CША                                                  0.000000
#  D.C                                                 46.643836
#  D.C.                                                 0.000000
#  Dalarna Sweden                                       0.000000
#  Danmark                                             40.929452
# ...                                                        ...
# слобода Даниловка Усть-Медведицкого округа Рост...   74.556164
# слобода Кабанья Купянского уезда Харьковской гу...   86.131507
# смт. Гребінки Київської області Васильківського...    0.000000
# ст. Асса Жамбылский район (Жамбылская область) ...   47.605479
# станица Кочетковская                                 76.624658
# станица Ново-Дмитриевская Краснодарского края        65.649315
# станица Скуришенская Волгоградской области            0.000000
# станица Удельная (ныне Ленинградская область)        51.654795
# станции Котово Окуловского района Новгородской ...   53.586301
# станция Антибес Мариинского района Кемеровской ...   51.298630
# станция Голицыно под Москвой                         51.082192
# станция Чебеньки Оренбургской обл.                   69.331507
# стойбище Муха Нанайского района Хабаровского края     0.000000
# столичный округ Токио                                 0.000000
# сяло Крушнік Мазырскага раёну Гомельскай вобласьці    0.000000
# там же                                               55.289498
# у місті Зіньків Полтавської області                   0.000000
# убит бандитами                                       37.123288
# урочище Тиит Арыы 4-го Мальжагарского наслега З...   50.649315
# фамильное имение Лапцы под Петербургом               75.539726
# форт Лазаревский                                     36.742466
# хут. Незаймановский Кубанской области                50.115068
# хут. Тогузак Троицкого р-на Челябинской обл.          0.000000
# хутор Пухляковском Ростовской области                91.904110
# хутор Язовец Несвижского района Минской области       0.000000
# хутор неподалеку г. Брест (Беларусь)                194.115068
# шахта Новая Селимская в 18 км от Алапаевска          21.564384
# штат Миннесот                                        84.695890
# штат Небраска                                        69.895890
# Շահկերտ                                              74.000000
#
# [3738 rows x 1 columns]

# %%
    # Суммарное количество книг авторов в зависимости от страны
    values = np.argsort(dataframe.num_books).values
    dataframeSorted = dataframe.iloc[values].tail(1)
    maximumBooks = dataframeSorted.num_books.tolist()[0]
    writer = dataframeSorted.name.tolist()[0]
    print("maximum books written: {maximumBooks} by writer {writer}".format(
        maximumBooks=maximumBooks,
        writer=writer))

    # Найти среднее число почитателей по всем авторам
    avgAdepts = dataframe.mean().adepts
    print("average adepts:", avgAdepts)

# %%
    # Среднее количество почитателей в зависимости от страны
    values = np.argsort(dataframe.num_books).values
    dataframeSorted = dataframe.iloc[values].tail(1)
    maximumBooks = dataframeSorted.num_books.tolist()[0]
    writer = dataframeSorted.name.tolist()[0]
    print("maximum books written: {maximumBooks} by writer {writer}".format(
        maximumBooks=maximumBooks,
        writer=writer))

# %%
    # Распределение первой буквы в зависимости от страны
    avgAdepts = dataframe.mean().adepts
    print("average adepts:", avgAdepts)

# %%
# Есть ли зависимость между возрастом и количеством произведений
fig, ax1 = plt.subplots(1, 1, figsize=(12,8))
ax1.plot(dataframe['lifespan'], dataframe['num_books'], 'o')

# %%
# Есть ли корреляция между именем и продолжительностью жизни
